# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
#What is Matplotlib
print("""Matplotlib is a popular 
data visualization library in Python used 
to create high-quality static, animated, and 
interactive visualizations in Python""")
# Out:
# Matplotlib is a popular
# data visualization library in Python used
# to create high-quality static, animated, and
# interactive visualizations in Python

# %%
#Why is it used
print("""It is used by data scientists
, analysts, and researchers
to create informative visualizations""")
# Out:
# It is used by data scientists
# , analysts, and researchers
# to create informative visualizations

# %%
print("""Line Plot: A line plot is a type of plot that displays data as a series of points
connected by straight lines. Line plots are useful for showing trends in data over time.

Scatter Plot: A scatter plot is a type of plot that displays data as a set of points. Scatter
plots are useful for showing the relationship between two variables.

Bar Plot: A bar plot is a type of plot that displays data as rectangular bars. Bar plots are
useful for comparing data across different categories.

Histogram: A histogram is a type of plot that displays the distribution of a dataset.
Histograms are useful for showing the frequency distribution of a set of continuous or discrete data.

Pie Chart: A pie chart is a type of plot that displays data as a circle divided into wedges.
Pie charts are useful for showing the proportion of each category in a dataset.



""")
# Out:
# Line Plot: A line plot is a type of plot that displays data as a series of points
# connected by straight lines. Line plots are useful for showing trends in data over time.
#
# Scatter Plot: A scatter plot is a type of plot that displays data as a set of points. Scatter
# plots are useful for showing the relationship between two variables.
#
# Bar Plot: A bar plot is a type of plot that displays data as rectangular bars. Bar plots are
# useful for comparing data across different categories.
#
# Histogram: A histogram is a type of plot that displays the distribution of a dataset.
# Histograms are useful for showing the frequency distribution of a set of continuous or discrete data.
#
# Pie Chart: A pie chart is a type of plot that displays data as a circle divided into wedges.
# Pie charts are useful for showing the proportion of each category in a dataset.

# %% [markdown]
# What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
print("""A scatter plot is a type of plot that displays data as a set of points""")
# Out:
# A scatter plot is a type of plot that displays data as a set of points

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
print("The subplot() function in Matplotlib is used to create multiple plots in a single figure.")
# Out:
# The subplot() function in Matplotlib is used to create multiple plots in a single figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title("line1")

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title("line2")

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title("line3")

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title("line4")

plt.suptitle("four line plots")
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
print("""A bar plot is a type of data visualization 
that displays data in rectangular bars with lengths
proportional to the values they represent""")
# Out:
# A bar plot is a type of data visualization
# that displays data in rectangular bars with lengths
# proportional to the values they represent

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
plt.xlabel("company")
plt.ylabel("profit")
plt.title("company profit")
plt.show()

plt.barh(company,profit)
plt.xlabel("company")
plt.ylabel("profit")
plt.title("company profit")
plt.show()

# %% [markdown]
# What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
print("A box plot is a type of graphical representation that displays the distribution of a dataset using quartiles")
# Out:
# A box plot is a type of graphical representation that displays the distribution of a dataset using quartiles

# %%
print("Box plots are used to provide a visual summary of a dataset, including its central tendency, variability, and any outliers.")
# Out:
# Box plots are used to provide a visual summary of a dataset, including its central tendency, variability, and any outliers.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)


data = [box1, box2]
fig, ax = plt.subplots()
ax.boxplot(data)

ax.set_xticklabels(['Box 1', 'Box 2'])
ax.set_ylabel('Data Values')
ax.set_title('Box Plot of Two Datasets')

plt.show()
